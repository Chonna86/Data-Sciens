# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

file_path = "D:/PythonProjects/MY_PYTHON_WAY/PYTHON_DATA-SCIENS/HomeWork_2/2017_jun_final - 2017_jun_final.csv"
df = pd.read_csv(file_path)
print(df.head())
# Out:
#    N                    Посада Мова програмування Спеціалізація  \
# 0  1        Junior QA engineer                NaN     Manual QA
# 1  2        Junior QA engineer                NaN     Manual QA
# 2  3         Software Engineer            C#/.NET           NaN
# 3  4         Software Engineer         JavaScript           NaN
# 4  5  Senior Software Engineer         JavaScript           NaN
#
#   Загальний досвід роботи Досвід роботи на поточному місці  \
# 0                     0.5                              0.5
# 1         менше 3 місяців                  менше 3 місяців
# 2                       4                                1
# 3                       5                                4
# 4       10 і більше років                              0.5
#
#    Зарплата на місяць  Зміна зарплати за 12 місяців   Місто   Розмір компанії  \
# 0                 400                             0  Харків        до 10 осіб
# ...

# %%
print(df.shape)
# Out:
# (8704, 25)

# %%
print(df.dtypes)
# Out:
# N                                     int64
# Посада                               object
# Мова програмування                   object
# Спеціалізація                        object
# Загальний досвід роботи              object
# Досвід роботи на поточному місці     object
# Зарплата на місяць                    int64
# Зміна зарплати за 12 місяців          int64
# Місто                                object
# Розмір компанії                      object
# Тип компанії                         object
# Стать                                object
# Вік                                   int64
# Освіта                               object
# Університет                          object
# Ще студент                             bool
# Рівень англійської                   object
# Предметна область                    object
# Дата заповнення                      object
# User.Agent                           object
# exp                                 float64
# ...

# %%
missing_values = df.isnull().sum()/df.shape[0]
print(missing_values)
# Out:
# N                                   0.000000
# Посада                              0.000000
# Мова програмування                  0.442325
# Спеціалізація                       0.829389
# Загальний досвід роботи             0.000000
# Досвід роботи на поточному місці    0.000000
# Зарплата на місяць                  0.000000
# Зміна зарплати за 12 місяців        0.000000
# Місто                               0.000000
# Розмір компанії                     0.000000
# Тип компанії                        0.000000
# Стать                               0.000000
# Вік                                 0.000000
# Освіта                              0.000000
# Університет                         0.041131
# Ще студент                          0.000000
# Рівень англійської                  0.000000
# Предметна область                   0.025620
# Дата заповнення                     0.000000
# User.Agent                          0.000000
# exp                                 0.000000
# ...

# %%
columns_to_check = df.columns.difference(['Мова програмування'])
df_cleaned = df.dropna(subset=columns_to_check)
print(df_cleaned.head())
# Out:
#          N        Посада Мова програмування  Спеціалізація  \
# 3649  3650  QA Tech Lead                NaN  Automation QA
#
#      Загальний досвід роботи Досвід роботи на поточному місці  \
# 3649                       9                                3
#
#       Зарплата на місяць  Зміна зарплати за 12 місяців   Місто  \
# 3649                6000                           500  Дніпро
#
#      Розмір компанії  ... Ще студент       Рівень англійської  \
# 3649    до 1000 осіб  ...      False  Elementary (початковий)
#
#                  Предметна область      Дата заповнення  \
# 3649  Фінанси та банкінг,eCommerce  13/06/2017 22:22:50
#
#                                              User.Agent  exp current_job_exp  \
# 3649  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  9.0             3.0
#
#      salary Валюта cls
# 3649   6000      h  QA
#
# [1 rows x 25 columns]

# %%
cleaned_shape = df_cleaned.shape


missing_values_percentage = df_cleaned.isnull().mean() * 100

print("Розмір оновленого датафрейму:", cleaned_shape)
print("Частка пропусків у кожному стовпці:")
print(missing_values_percentage)
# Out:
# Розмір оновленого датафрейму: (1, 25)
# Частка пропусків у кожному стовпці:
# N                                     0.0
# Посада                                0.0
# Мова програмування                  100.0
# Спеціалізація                         0.0
# Загальний досвід роботи               0.0
# Досвід роботи на поточному місці      0.0
# Зарплата на місяць                    0.0
# Зміна зарплати за 12 місяців          0.0
# Місто                                 0.0
# Розмір компанії                       0.0
# Тип компанії                          0.0
# Стать                                 0.0
# Вік                                   0.0
# Освіта                                0.0
# Університет                           0.0
# Ще студент                            0.0
# Рівень англійської                    0.0
# Предметна область                     0.0
# Дата заповнення                       0.0
# User.Agent                            0.0
# ...

# %%
df_cleaned = df.dropna()
cleaned_shape = df_cleaned.shape
print("Розмір оновленого датафрейму після видалення рядків з пропущеними значеннями:", cleaned_shape)
# Out:
# Розмір оновленого датафрейму після видалення рядків з пропущеними значеннями: (0, 25)

# %%
grouped_by_position = df.groupby('Посада')

for position, group in grouped_by_position:
    print("Посада:", position)
    print(group.head())
    print()


fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

for position, group in grouped_by_position:
    x = group.index
    y = group['Зарплата на місяць']
    z = group['exp']
    ax.plot_trisurf(x, y, z, linewidth=0.2)

ax.set_xlabel('Індекс рядка')
ax.set_ylabel('Зарплата на місяць')
ax.set_zlabel('Досвід роботи')
ax.set_title('Діаграма з конусами')

plt.show()
# Out:
# Посада: Business analyst
#        N            Посада Мова програмування Спеціалізація  \
# 136  137  Business analyst                NaN           NaN
# 226  227  Business analyst                NaN           NaN
# 254  255  Business analyst                NaN           NaN
# 297  298  Business analyst                NaN           NaN
# 338  339  Business analyst                NaN           NaN
#
#     Загальний досвід роботи Досвід роботи на поточному місці  \
# 136                       7                             0.25
# 226                       3                  менше 3 місяців
# 254                       3                                2
# 297                       4                              1.5
# 338                       6                                1
#
#      Зарплата на місяць  Зміна зарплати за 12 місяців  Місто  \
# 136                2500                           800   Київ
# 226                1500                             0  Одеса
# ...

# %%
file_path = "D:/PythonProjects/MY_PYTHON_WAY/PYTHON_DATA-SCIENS/HomeWork_2/2017_jun_final - 2017_jun_final.csv"
df = pd.read_csv(file_path)
aggregated_salary = df.groupby('Посада')['Зарплата на місяць'].agg(['min', 'max'])
print(aggregated_salary)

plt.figure(figsize=(10, 8))
sns.set(style="whitegrid")
sns.barplot(x=aggregated_salary.index, y='min', data=aggregated_salary, color='skyblue')
sns.barplot(x=aggregated_salary.index, y='max', data=aggregated_salary, color='salmon')
plt.title('Мінімальна та максимальна зарплата за посадами')
plt.xlabel('Посада')
plt.ylabel('Зарплата на місяць')
plt.xticks(rotation=90)
plt.legend(['Мінімальна зарплата', 'Максимальна зарплата'])
plt.show()
# Out:
#                                              min    max
# Посада
# Business analyst                             200   5000
# DBA                                          380   6000
# Data Scientist / Data Analyst                150   8000
# Designer                                     100   4000
# DevOps                                       194  10000
# Director of Engineering / Program Director  1500  34000
# ERP / CRM                                    100   6000
# Game designer                                150   6800
# HR                                           100   7000
# HTML coder                                   154   3000
# Junior QA engineer                            96   2000
# Junior Software Engineer                      75   2600
# Marketing                                    100   4000
# Product Manager                              250   5000
# Project manager                              190   8000
# QA Tech Lead                                 430   6000
# ...

# %%
def fill_avg_salary(row):
    return df['Зарплата на місяць'].mean()

df['avg'] = df.apply(fill_avg_salary, axis=1)
plt.figure(figsize=(10, 6))
plt.scatter(df.index, df['avg'], color='blue', alpha=0.5)
plt.title('Середня зарплата для кожного рядка')
plt.xlabel('Індекс рядка')
plt.ylabel('Середня зарплата')
plt.grid(True)
plt.show()

# %%
print(df['avg'].describe())
# Out:
# count    8704.000000
# mean     1666.704159
# std         0.000000
# min      1666.704159
# 25%      1666.704159
# 50%      1666.704159
# 75%      1666.704159
# max      1666.704159
# Name: avg, dtype: float64

# %%
df.to_csv('output.csv', index=False)
